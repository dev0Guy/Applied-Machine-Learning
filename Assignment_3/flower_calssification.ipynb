# %% [markdown]
# # Transfer Learning - Flower Classification

# %% [markdown]
# First, We should install & import all packages

# %%
# %pip install torch
# %pip install torchvision
# %pip install scipy 
# %pip install torchsummary
# %pip install tqdm 
# %pip install opencv-python
# %pip install albumentations==0.4.6
# Out:
# Requirement already satisfied: torch in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (1.11.0)
# Requirement already satisfied: typing-extensions in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torch) (4.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: torchvision in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (0.12.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torchvision) (9.1.1)
# Requirement already satisfied: torch==1.11.0 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: requests in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: typing-extensions in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torchvision) (4.2.0)
# Requirement already satisfied: numpy in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from torchvision) (1.22.4)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from requests->torchvision) (2022.5.18.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: scipy in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from scipy) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: torchsummary in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tqdm in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (4.64.0)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from tqdm) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: opencv-python in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (4.6.0.66)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy>=1.17.3; python_version >= "3.8" in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from opencv-python) (1.22.4)
# Requirement already satisfied: albumentations==0.4.6 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (0.4.6)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from albumentations==0.4.6) (1.22.4)
# Requirement already satisfied: scipy in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from albumentations==0.4.6) (1.8.1)
# Requirement already satisfied: imgaug>=0.4.0 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from albumentations==0.4.6) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from albumentations==0.4.6) (6.0)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from albumentations==0.4.6) (4.6.0.66)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (0.19.2)
# Requirement already satisfied: Shapely in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (1.8.2)
# Requirement already satisfied: Pillow in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (9.1.1)
# Requirement already satisfied: matplotlib in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (3.5.2)
# Requirement already satisfied: imageio in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (2.19.3)
# Requirement already satisfied: six in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (21.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (2.8.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (2022.5.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in c:\users\david\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.1; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\Users\david\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import torch
import torchvision
from tqdm import tqdm
import glob
import cv2
import numpy as np
from albumentations.pytorch import ToTensorV2
import albumentations as A  
import scipy.io
from functools import cmp_to_key
from torch.utils.data import Dataset,DataLoader
from torchvision.transforms import ToTensor
import torchvision.models as models
from torchvision.io import read_image
from torchsummary import summary 
import matplotlib.pyplot as plt
import torchvision.transforms as T
from sklearn.model_selection import train_test_split
import json
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lets Fech The Data

# %%
labels = scipy.io.loadmat('imagelabels.mat')['labels'][0]
imgs_path = glob.glob("jpg/*")

# %% [markdown]
# ### Sort For Easy Excess

# %%
def cmp_file_names(item1, item2):
    item1 = int(item1.split("_")[1].replace('.jpg',''))
    item2 = int(item2.split("_")[1].replace('.jpg',''))   
    return item1 - item2
imgs_path = np.array(sorted(imgs_path,key=cmp_to_key(cmp_file_names)))
labels = np.array(labels)

# %% [markdown]
# #### Combine Path & labels

# %%
def divide_train_test_split(test_size=0.25,val_size=0.25):
    X_train, X_test, y_train, y_test = train_test_split(imgs_path, labels, test_size=test_size, random_state=1)
    val_size = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_size, random_state=1) 
    return {
        'train': (X_train,y_train),
        'validation': (X_val,y_val),
        'test': (X_test,y_test),
    }
divide_train_test_split()
# Out:
# {'train': (array(['jpg\\image_06462.jpg', 'jpg\\image_04103.jpg',
#          'jpg\\image_02324.jpg', ..., 'jpg\\image_04255.jpg',
#          'jpg\\image_00974.jpg', 'jpg\\image_03638.jpg'], dtype='<U19'),
#   array([33, 29, 43, ..., 18, 46, 72], dtype=uint8)),
#  'validation': (array(['jpg\\image_04100.jpg', 'jpg\\image_06602.jpg',
#          'jpg\\image_03642.jpg', ..., 'jpg\\image_05294.jpg',
#          'jpg\\image_06449.jpg', 'jpg\\image_04543.jpg'], dtype='<U19'),
#   array([29, 25, 53, ..., 70, 33, 71], dtype=uint8)),
#  'test': (array(['jpg\\image_03892.jpg', 'jpg\\image_06722.jpg',
#          'jpg\\image_03415.jpg', ..., 'jpg\\image_04550.jpg',
#          'jpg\\image_06489.jpg', 'jpg\\image_04493.jpg'], dtype='<U19'),
#   array([17, 79, 23, ..., 71, 26, 71], dtype=uint8))}

# %% [markdown]
# ### Import Pretrained Model

# %%
vgg16 = models.vgg16(pretrained=True)
alexnet= models.alexnet(pretrained=True)

N_CLASS = 102

# %%
for param in vgg16.classifier[6].parameters():
    param.requires_grad = True
for param in alexnet.classifier[6].parameters():
    param.requires_grad = True

# %% [markdown]
# Crete the customize network and visulize it

# %%
classifer1 = torch.nn.Sequential(
    vgg16,
    torch.nn.Linear(in_features=1_000,out_features=N_CLASS),
)

classifer2 = torch.nn.Sequential(
    alexnet,
    torch.nn.Linear(in_features=1_000,out_features=N_CLASS),
)

# %%
summary(classifer1, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 7, 7]               0
#            Linear-33                 [-1, 4096]     102,764,544
#              ReLU-34                 [-1, 4096]               0
#           Dropout-35                 [-1, 4096]               0
#            Linear-36                 [-1, 4096]      16,781,312
#              ReLU-37                 [-1, 4096]               0
#           Dropout-38                 [-1, 4096]               0
#            Linear-39                 [-1, 1000]       4,097,000
#               VGG-40                 [-1, 1000]               0
#            Linear-41                  [-1, 102]         102,102
# ================================================================
# Total params: 138,459,646
# Trainable params: 138,459,646
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.79
# Params size (MB): 528.18
# Estimated Total Size (MB): 747.55
# ----------------------------------------------------------------

# %%
summary(classifer2, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                 [-1, 1000]       4,097,000
#           AlexNet-22                 [-1, 1000]               0
#            Linear-23                  [-1, 102]         102,102
# ================================================================
# Total params: 61,202,942
# Trainable params: 61,202,942
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.39
# Params size (MB): 233.47
# Estimated Total Size (MB): 242.43
# ----------------------------------------------------------------

# %% [markdown]
# After building the model we should define all hyper paramters

# %% [markdown]
# we almost there, the only need is to import and use the data. Torch uses Dataset & DataLoader,
# To do Just that!

# %%
class ImgDataset(Dataset):
    
    def __init__(self, data_tuple, transform, target_transform=None):
        self.imgs_path, self.labels = data_tuple
        self.transform = transform
    
    def __len__(self):
        # return len(self.labels)
        return 20

    def __getitem__(self, idx):
        img_path = self.imgs_path[idx]
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        transformed = self.transform(image=img)
        img = transformed['image']
        img = T.Resize(IMG_SIZE)(img)
        label = torch.zeros((N_CLASS))
        label[self.labels[idx]-1] = 1
        return img, label.float()

# %% [markdown]
# we need to create the data loader each time for diffrent eval & test for each epoch

# %%
def create_data_splits(transform):
    data_dict = divide_train_test_split()
    new_dict = dict()
    for key,val in data_dict.items():
        ds = ImgDataset(val,transform)
        new_dict[key] = DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True)
    return new_dict

# %%
def accuracy(predictions,labels):
    return torch.sum(torch.argmax(labels,axis=1) ==  torch.argmax(predictions,axis=1))

# %% [markdown]
# #### Training | Test | Validation Loop

# %%
def train(train_loader,model,optimizer,criterion):
    model.train()
    running_loss = 0.
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        running_loss += loss.item()
        optimizer.step()
    return running_loss

# %%
def validation(validation_loader,model,criterion):
    model.eval()
    acc, running_loss = 0 , 0
    for inputs, labels in validation_loader: 
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        acc += accuracy(outputs, labels)
    return running_loss, int(acc/len(validation_loader.dataset))

# %%
def train_validation(train_loader,validation_loader,model,optimizer,criterion,epoch_num=1):
    model.train()
    meta_by_epoch = {
        'train': { 'loss': []},
        'validation': { 'loss': [], 'accuracy': []},
    }
    for ep in range(epoch_num):
        meta_by_epoch['train']['loss'].append(train(train_loader,model,optimizer,criterion))
        val_data = validation(validation_loader,model,criterion)
        meta_by_epoch['validation']['loss'].append(val_data[0])
        meta_by_epoch['validation']['accuracy'].append(val_data[1])
    return meta_by_epoch

# %%
def test(test_loader,model,optimizer,criterion):
    model.eval()
    acc, running_loss = 0 , 0
    for inputs, labels in test_loader: 
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        acc += accuracy(outputs, labels)
        
    return running_loss , int(acc/test_loader.dataset)

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 16

# %%
transforms_train = A.Compose([
    A.RandomResizedCrop(height=IMG_SIZE[0],width=IMG_SIZE[1],p=0.2),
    A.Normalize(),   
    A.Flip(),# normalize
    ToTensorV2(),
    # shift channels to be first rather than last and convert to torch tensor
])

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    # mean = np.array([0.485, 0.456, 0.406])
    # std = np.array([0.229, 0.224, 0.225])
    # inp = std * inp + mean
    plt.figure(figsize=(10, 10), dpi=120)
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)# pause a bit so that plots are updated
    pass

data = create_data_splits(transforms_train)
# # Get a batch of training data
inputs, classes = next(iter(data['train']))
# Make a grid from batch
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[ int(torch.argmax(x)) for x in classes])

# %%
def runner(classifer,transform,n_epochs):
    optimizer = torch.optim.SGD(classifer.parameters(), lr=0.001, momentum=0.9)
    criterion = torch.nn.CrossEntropyLoss()
    runinng_meta = []
    for r_n in range(2):
        data = create_data_splits(transform)
        meta = train_validation(data['train'],data['validation'],classifer,optimizer,criterion,epoch_num=5)
        test_data = test(data['test'],classifer,optimizer,criterion)
        meta['test'] = {}
        meta['test']['loss'] = test_data[0]
        meta['test']['accuracy'] = test_data[1]
        print("+++++++++++")
        print(meta)
        print("+++++++++++")
        runinng_meta.append(meta)
    return runinng_meta

# %%
vgg_data = runner(classifer=classifer1,transform=transforms_train,n_epochs=20)
alexnet_data = runner(classifer=classifer2,transform=transforms_train,n_epochs=20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\david\OneDrive\שולחן העבודה\לימודים\שנה ד\למידה חישובית\עבודה 3\flower_calssification.ipynb Cell 34' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000033?line=0'>1</a> vgg_data = runner(classifer=classifer1,transform=transforms_train,n_epochs=20)
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000033?line=1'>2</a> alexnet_data = runner(classifer=classifer2,transform=transforms_train,n_epochs=20)
#
# c:\Users\david\OneDrive\שולחן העבודה\לימודים\שנה ד\למידה חישובית\עבודה 3\flower_calssification.ipynb Cell 33' in runner(classifer, transform, n_epochs)
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000032?line=5'>6</a> data = create_data_splits(transform)
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000032?line=6'>7</a> meta = train_validation(data['train'],data['validation'],classifer,optimizer,criterion,epoch_num=5)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000032?line=7'>8</a> test_data = test(data['test'],classifer,optimizer,criterion)
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000032?line=8'>9</a> meta['test'] = {}
#      <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000032?line=9'>10</a> meta['test']['loss'] = test_data[0]
#
# c:\Users\david\OneDrive\שולחן העבודה\לימודים\שנה ד\למידה חישובית\עבודה 3\flower_calssification.ipynb Cell 29' in test(test_loader, model, optimizer, criterion)
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000028?line=6'>7</a>     running_loss += loss.item()
#       <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000028?line=7'>8</a>     acc += accuracy(outputs, labels)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/david/OneDrive/%D7%A9%D7%95%D7%9C%D7%97%D7%9F%20%D7%94%D7%A2%D7%91%D7%95%D7%93%D7%94/%D7%9C%D7%99%D7%9E%D7%95%D7%93%D7%99%D7%9D/%D7%A9%D7%A0%D7%94%20%D7%93/%D7%9C%D7%9E%D7%99%D7%93%D7%94%20%D7%97%D7%99%D7%A9%D7%95%D7%91%D7%99%D7%AA/%D7%A2%D7%91%D7%95%D7%93%D7%94%203/flower_calssification.ipynb#ch0000028?line=9'>10</a> return running_loss , int(acc/test_loader.dataset)
#
# TypeError: unsupported operand type(s) for /: 'Tensor' and 'ImgDataset'

# %%
with open('vgg.json','w') as fp:
    json.dump(vgg_data,fp)

with open('alexnet.json','w') as fp:
    json.dump(alexnet_data,fp)

# %%
def plot_train_validation_losses(model_name, data):
    fig, ax = plt.subplots(1,2)
    fig.set_size_inches(10,10)
    fig.set_dpi(100)
    fig.suptitle(f'{model_name} - Train & Validation Losses',fontsize=20)
    for c_idx in range(ax.shape[0]):
        train_data = data[c_idx]['train']
        validation_data = data[c_idx]['validation']
        ax[c_idx].plot(train_data['loss'],label='train')
        ax[c_idx].plot(validation_data['loss'],label='validation')
        ax[c_idx].legend(loc='lower right')
        ax[c_idx].set_xlabel('Epoches')
        ax[c_idx].set_ylabel('Cross Entropy Loss')
        ax[c_idx].set_title(f'Run Number: {c_idx+1}')

# %%
def plot_test_accuracy(vgg_data,alexnet_data,names=['VGG','AlexNet']):

    vgg_test = [data['test']['accuracy'] for data in vgg_data]
    alexnet_test = [data['test']['accuracy'] for data in alexnet_data]


    X_axis = np.arange(len(names))
    
    plt.bar(X_axis - 0.2, vgg_test, 0.4, label = names[0])
    plt.bar(X_axis + 0.2, alexnet_test, 0.4, label = names[1])
    
    plt.xticks(X_axis, names)
    plt.xlabel("Models")
    plt.ylabel("Test Accuracy")
    plt.title("Compare Accuracy Of Both Models")
    plt.legend()
    plt.show()

# %%
plot_train_validation_losses('VGG',vgg_data)

# %%
plot_train_validation_losses('AlexNet',alexnet_data)

# %%
plot_test_accuracy(vgg_data,alexnet_data)
